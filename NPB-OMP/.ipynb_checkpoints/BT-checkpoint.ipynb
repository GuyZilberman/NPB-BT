# %% [markdown]
# ## Shared Local Memory Size and Work-group Size
# Run The fully offloaded version of BT

# %%
# Set the class and the number of CPU threads
CLASS = 'A'
NUM_THREADS = 112

# Compile and run
# !cp BT/GPU_Only/bt.cpp BT/
# !bash BT/script.sh A 112
# !rm BT/bt.cpp
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Using OMP_NUM_THREADS = 112
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ...
#    =      NAS PARALLEL BENCHMARKS 4.1        =
#    =      OpenMP Versions                    =
#    =      C++                                =
# ...
#
# cd BT; make CLASS=A
# make[1]: Entering directory '/home/u9a7a1473bfa5fc0c75e999ec9571fa9/Project/NPB-BT/NPB-OMP/BT'
# make[2]: Entering directory '/home/u9a7a1473bfa5fc0c75e999ec9571fa9/Project/NPB-BT/NPB-OMP/sys'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/u9a7a1473bfa5fc0c75e999ec9571fa9/Project/NPB-BT/NPB-OMP/sys'
# ../sys/setparams bt A
# icpx -std=c++14  -c -I../common  -O3 -fiopenmp -mcmodel=medium -fopenmp-targets=spir64 bt.cpp
# icpx -std=c++14 -O3 -fiopenmp -mcmodel=medium -fopenmp-targets=spir64 -o ../bin/bt.A bt.o ../common/c_print_results.o ../common/c_timers.o ../common/c_wtime.o -lm
# ...
